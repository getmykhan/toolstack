# %%
import pandas as pd
import numpy as np
from toolstack.text import TextPreprocessing, AutomatedTextPreprocessing, word_count
from toolstack.feature import LabelEncoder, CountEncoder, TargetEncoder

# %%
df = pd.read_csv('amazon-review-300.csv', header=-1)

# %%
df.head()
# Out:
#    0                                                  1  \
# 0  2                     Stuning even for the non-gamer
# 1  2              The best soundtrack ever to anything.
# 2  2                                           Amazing!
# 3  2                               Excellent Soundtrack
# 4  2  Remember, Pull Your Jaw Off The Floor After He...
#
#                                                    2
# 0  This sound track was beautiful! It paints the ...
# 1  I'm reading a lot of reviews saying that this ...
# 2  This soundtrack is my favorite music of all ti...
# 3  I truly like this soundtrack and I enjoy video...
# 4  If you've played the game, you know how divine...

# %%
df = word_count(df, 1).head()

# %%
df = df.append(df.head())

# %%
le = LabelEncoder(df, 'Words')

# %%
le.stack()

# %%
le.unstack()
# Out:
#      Words  Count
# 0        0      1
# 494      1      1
# 495      2      1
# 496      3      1
# 497      4      1
# 0        0      1
# 494      1      1
# 495      2      1
# 496      3      1
# 497      4      1

# %%
from toolstack.utils import load_dataset

# %%
load_dataset('Weather')['play'].value_counts().to_dict()
# Out:
# {'Yes': 9, 'No': 5}

# %%
df = load_dataset('Weather')

# %%
ce = CountEncoder(df, 'temp', False)

# %%
ce.stack()

# %%
np.log(5)
# Out:
# 1.6094379124341003

# %%
np.log(9)
# Out:
# 2.1972245773362196

# %%
ce.unstack()
# Out:
#     day   outlook  temp humidity    wind play
# 0    D1     Sunny     4     High    Weak   No
# 1    D2     Sunny     4     High  Strong   No
# 2    D3  Overcast     4     High    Weak  Yes
# 3    D4      Rain     6     High    Weak  Yes
# 4    D5      Rain     4   Normal    Weak  Yes
# 5    D6      Rain     4   Normal  Strong   No
# 6    D7  Overcast     4   Normal  Strong  Yes
# 7    D8     Sunny     6     High    Weak   No
# 8    D9     Sunny     4   Normal    Weak  Yes
# 9   D10      Rain     6   Normal    Weak  Yes
# 10  D11     Sunny     6   Normal  Strong  Yes
# 11  D12  Overcast     6     High  Strong  Yes
# 12  D13  Overcast     4   Normal    Weak  Yes
# 13  D14      Rain     6     High  Strong   No

# %%
df
# Out:
#     day   outlook  temp humidity    wind play
# 0    D1     Sunny   Hot     High    Weak   No
# 1    D2     Sunny   Hot     High  Strong   No
# 2    D3  Overcast   Hot     High    Weak  Yes
# 3    D4      Rain  Mild     High    Weak  Yes
# 4    D5      Rain  Cool   Normal    Weak  Yes
# 5    D6      Rain  Cool   Normal  Strong   No
# 6    D7  Overcast  Cool   Normal  Strong  Yes
# 7    D8     Sunny  Mild     High    Weak   No
# 8    D9     Sunny  Cool   Normal    Weak  Yes
# 9   D10      Rain  Mild   Normal    Weak  Yes
# 10  D11     Sunny  Mild   Normal  Strong  Yes
# 11  D12  Overcast  Mild     High  Strong  Yes
# 12  D13  Overcast   Hot   Normal    Weak  Yes
# 13  D14      Rain  Mild     High  Strong   No

# %%
te = TargetEncoder(df, 'day', 'play')

# %%
te.stack()

# %%
te.unstack()
# Out:
#     day   outlook  temp humidity    wind play
# 0     5     Sunny   Hot     High    Weak   No
# 1     5     Sunny   Hot     High  Strong   No
# 2     9  Overcast   Hot     High    Weak  Yes
# 3     9      Rain  Mild     High    Weak  Yes
# 4     9      Rain  Cool   Normal    Weak  Yes
# 5     5      Rain  Cool   Normal  Strong   No
# 6     9  Overcast  Cool   Normal  Strong  Yes
# 7     5     Sunny  Mild     High    Weak   No
# 8     9     Sunny  Cool   Normal    Weak  Yes
# 9     9      Rain  Mild   Normal    Weak  Yes
# 10    9     Sunny  Mild   Normal  Strong  Yes
# 11    9  Overcast  Mild     High  Strong  Yes
# 12    9  Overcast   Hot   Normal    Weak  Yes
# 13    5      Rain  Mild     High  Strong   No

# %%
df[df['outlook'] == 'Sunny']['play'].value_counts()
# Out:
# No     3
# Yes    2
# Name: play, dtype: int64

# %%
df['outlook'].unique().tolist()
# Out:
# ['Sunny', 'Overcast', 'Rain']

# %%
len(df[(df['outlook'] == 'Sunny') & (df['play'] == 'No')]) / len(df[(df['outlook'] == 'Sunny')])
# Out:
# 0.6

# %%
df[(df['outlook'] == 'Sunny')]
# Out:
#     day outlook  temp humidity    wind play
# 0    D1   Sunny   Hot     High    Weak   No
# 1    D2   Sunny   Hot     High  Strong   No
# 7    D8   Sunny  Mild     High    Weak   No
# 8    D9   Sunny  Cool   Normal    Weak  Yes
# 10  D11   Sunny  Mild   Normal  Strong  Yes

# %%
df
# Out:
#     day   outlook  temp humidity    wind play
# 0    D1     Sunny   Hot     High    Weak   No
# 1    D2     Sunny   Hot     High  Strong   No
# 2    D3  Overcast   Hot     High    Weak  Yes
# 3    D4      Rain  Mild     High    Weak  Yes
# 4    D5      Rain  Cool   Normal    Weak  Yes
# 5    D6      Rain  Cool   Normal  Strong   No
# 6    D7  Overcast  Cool   Normal  Strong  Yes
# 7    D8     Sunny  Mild     High    Weak   No
# 8    D9     Sunny  Cool   Normal    Weak  Yes
# 9   D10      Rain  Mild   Normal    Weak  Yes
# 10  D11     Sunny  Mild   Normal  Strong  Yes
# 11  D12  Overcast  Mild     High  Strong  Yes
# 12  D13  Overcast   Hot   Normal    Weak  Yes
# 13  D14      Rain  Mild     High  Strong   No

# %%
3/5
# Out:
# 0.6

# %%
df = load_dataset('Weather')

# %%
df
# Out:
#     day   outlook  temp humidity    wind play
# 0    D1     Sunny   Hot     High    Weak   No
# 1    D2     Sunny   Hot     High  Strong   No
# 2    D3  Overcast   Hot     High    Weak  Yes
# 3    D4      Rain  Mild     High    Weak  Yes
# 4    D5      Rain  Cool   Normal    Weak  Yes
# 5    D6      Rain  Cool   Normal  Strong   No
# 6    D7  Overcast  Cool   Normal  Strong  Yes
# 7    D8     Sunny  Mild     High    Weak   No
# 8    D9     Sunny  Cool   Normal    Weak  Yes
# 9   D10      Rain  Mild   Normal    Weak  Yes
# 10  D11     Sunny  Mild   Normal  Strong  Yes
# 11  D12  Overcast  Mild     High  Strong  Yes
# 12  D13  Overcast   Hot   Normal    Weak  Yes
# 13  D14      Rain  Mild     High  Strong   No

# %%
te = TargetEncoder(df, 'temp', target='play', strategy='percentage')

# %%
te.stack()

# %%
te.unstack()
# Out:
#     day   outlook       temp humidity    wind play
# 0    D1     Sunny   0.142857     High    Weak   No
# 1    D2     Sunny   0.142857     High  Strong   No
# 2    D3  Overcast   0.142857     High    Weak  Yes
# 3    D4      Rain   0.285714     High    Weak  Yes
# 4    D5      Rain   0.214286   Normal    Weak  Yes
# 5    D6      Rain  0.0714286   Normal  Strong   No
# 6    D7  Overcast   0.214286   Normal  Strong  Yes
# 7    D8     Sunny   0.142857     High    Weak   No
# 8    D9     Sunny   0.214286   Normal    Weak  Yes
# 9   D10      Rain   0.285714   Normal    Weak  Yes
# 10  D11     Sunny   0.285714   Normal  Strong  Yes
# 11  D12  Overcast   0.285714     High  Strong  Yes
# 12  D13  Overcast   0.142857   Normal    Weak  Yes
# 13  D14      Rain   0.142857     High  Strong   No

# %%
df
# Out:
#     day   outlook  temp humidity    wind play
# 0    D1     Sunny   Hot     High    Weak   No
# 1    D2     Sunny   Hot     High  Strong   No
# 2    D3  Overcast   Hot     High    Weak  Yes
# 3    D4      Rain  Mild     High    Weak  Yes
# 4    D5      Rain  Cool   Normal    Weak  Yes
# 5    D6      Rain  Cool   Normal  Strong   No
# 6    D7  Overcast  Cool   Normal  Strong  Yes
# 7    D8     Sunny  Mild     High    Weak   No
# 8    D9     Sunny  Cool   Normal    Weak  Yes
# 9   D10      Rain  Mild   Normal    Weak  Yes
# 10  D11     Sunny  Mild   Normal  Strong  Yes
# 11  D12  Overcast  Mild     High  Strong  Yes
# 12  D13  Overcast   Hot   Normal    Weak  Yes
# 13  D14      Rain  Mild     High  Strong   No

# %%
# Get the unique variables

# %%
# Get the unique Classes

# %%
d = df.groupby(['outlook', 'play']).count()[df.columns[0]].to_dict()

# %%
df.loc[(df['play'] == 'No') &( df['outlook'] == 'Rain') , 'outlook'] = 2

# %%
d
# Out:
# {('Overcast', 'Yes'): 4,
#  ('Rain', 'No'): 2,
#  ('Rain', 'Yes'): 3,
#  ('Sunny', 'No'): 3,
#  ('Sunny', 'Yes'): 2}

# %%
df['sunny'].apply(lambda x: [i for i in d])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'sunny'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-38-662b75966f24> in <module>
# ----> 1 df['sunny'].apply(lambda x: [i for i in d])
#
# ...
